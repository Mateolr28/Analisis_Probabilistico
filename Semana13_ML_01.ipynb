# %% [markdown]
# # Semana 13

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.datasets import make_classification

# %%
# Crear datos para regresión lineal simple
np.random.seed(1234)
X_simple = 2.5 * np.random.randn(100) + 1.5   # Feature
residuals = 0.5 * np.random.randn(100)       # Noise
y_simple = 2 + 0.3 * X_simple + residuals    # Target
df_simple = pd.DataFrame({'X': X_simple, 'y': y_simple})

# Crear datos para regresión lineal múltiple
X_multi = pd.DataFrame({
    'X1': np.random.rand(100) * 10,
    'X2': np.random.rand(100) * 5
})
y_multi = 1.5 + 0.4 * X_multi['X1'] + 0.8 * X_multi['X2'] + np.random.randn(100)

# Crear datos para regresión logística
X_logi, y_logi = make_classification(n_samples=200, n_features=2, 
                                     n_redundant=0, n_clusters_per_class=1, 
                                     flip_y=0.1, class_sep=1.5, random_state=0)
df_logi = pd.DataFrame(X_logi, columns=["X1", "X2"])
df_logi["target"] = y_logi

# %%
dataframe=df_logi

# %% [markdown]
# # Parte 1: Regresión líneal

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.linear_model import LinearRegression

# Usar df_simple creado anteriormente
sns.scatterplot(x='X', y='y', data=df_simple)
plt.title("Regresión lineal simple")
plt.show()

# %%
X = df_simple[['X']]
y = df_simple['y']

model = LinearRegression()
model.fit(X, y)

print(f"Pendiente: {model.coef_[0]}")
print(f"Intercepto: {model.intercept_}")
# Out:
# Pendiente: 0.3162828977798418
# Intercepto: 1.9490692674720669

# %%
df_simple['predicciones'] = model.predict(X)

plt.scatter(df_simple['X'], df_simple['y'], label='Datos reales')
plt.plot(df_simple['X'], df_simple['predicciones'], color='red', label='Línea de regresión')
plt.legend()
plt.title("Ajuste de la recta")
plt.show()

# %% [markdown]
# ¿Qué significa la pendiente?
#
# ¿Es buena la predicción visual?
